# %% [markdown]
# ##Respiratory Diseases : Coswara Dataset

# %%
# !git clone https://github.com/iiscleap/Coswara-Data.git
# Out:
# Cloning into 'Coswara-Data'...
# remote: Enumerating objects: 995, done.
# remote: Counting objects: 100% (197/197), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 995 (delta 112), reused 148 (delta 77), pack-reused 798
# Receiving objects: 100% (995/995), 15.97 GiB | 39.81 MiB/s, done.
# Resolving deltas: 100% (422/422), done.
# Updating files: 100% (336/336), done.

# %%
import pandas as pd

# %%
Metadata.head()
# Out:
#                              id   a covid_status record_date ep       g  \
# 0  iV3Db6t1T8b7c5HQY2TwxIhjbzD3  28      healthy  2020-04-23  y    male
# 1  AxuYWBN0jFVLINCBqIW5aZmGCdu1  25      healthy  2020-04-20  y    male
# 2  C5eIsssb9GSkaAgIfsHMHeR6fSh1  28      healthy  2020-04-24  y  female
# 3  YjbEAECMBIaZKyfqOvWy5DDImUb2  26      healthy  2020-04-23  y    male
# 4  aGOvk4ji0cVqIzCs1jHnzlw2UEy2  32      healthy  2020-04-22  y    male
#
#              l_c              l_l             l_s rU  ... vacc   bd  \
# 0          India        Anantapur  Andhra Pradesh  n  ...  NaN  NaN
# 1          India  BENGALURU URBAN       Karnataka  n  ...  NaN  NaN
# 2  United States       Pittsburgh    Pennsylvania  n  ...  NaN  NaN
# 3          India        Bangalore       Karnataka  n  ...  NaN  NaN
# 4          India          Nalanda           Bihar  n  ...  NaN  NaN
#
#   others_resp  ftg   st  ihd asthma  others_preexist  cld pneumonia
# ...

# %%
import os
from shutil import move
import glob

target_dir = "/content/extracted_data"
files_to_unzip = glob.glob("/content/Coswara-Data/20200413/*.tar.gz.ad")

for filename in files_to_unzip:
  source_path = filename
  dest_path = os.path.join(target_dir, os.path.basename(filename)[:-4])
  os.makedirs(dest_path, exist_ok=True)
  os.system(f"tar -xf {source_path} -C {dest_path}")
  os.remove(source_path)

# %%
wimport glob
import scipy

I = 0

audio = []

for i in Metadata['id']:
  print(id)
  I=I+1
  files = glob.glob(i)
  print(files)
  sample_rate, audio_data = scipy.io.wavfile.read(files[0])
  audio.append([audio_data,sample_rate])

  if I==6:
    break

# %%
import scipy.io.wavfile
import numpy


sample_rate, audio_data = scipy.io.wavfile.read('sample.wav')


audio_data = numpy.frombuffer(audio_data, dtype='int16')

# %%
newdf_cleaned = pd.read_csv("/content/cleaned_data(RESPERA).csv")

# %%
newdf_cleaned.head()
# Out:
#                              id  label  \
# 0  iV3Db6t1T8b7c5HQY2TwxIhjbzD3      0
# 1  AxuYWBN0jFVLINCBqIW5aZmGCdu1      1
# 2  C5eIsssb9GSkaAgIfsHMHeR6fSh1      0
# 3  YjbEAECMBIaZKyfqOvWy5DDImUb2      1
# 4  aGOvk4ji0cVqIzCs1jHnzlw2UEy2      0
#
#                                           full_paths  \
# 0  ['iV3Db6t1T8b7c5HQY2TwxIhjbzD3\\breathing-deep...
# 1  ['AxuYWBN0jFVLINCBqIW5aZmGCdu1\\breathing-deep...
# 2  ['C5eIsssb9GSkaAgIfsHMHeR6fSh1\\breathing-deep...
# 3  ['YjbEAECMBIaZKyfqOvWy5DDImUb2\\breathing-deep...
# 4  ['aGOvk4ji0cVqIzCs1jHnzlw2UEy2\\breathing-deep...
#
#                                          audio_paths  \
# 0  001Output_combined_audio\combined_audio_iV3Db6...
# 1  001Output_combined_audio\combined_audio_AxuYWB...
# 2  001Output_combined_audio\combined_audio_C5eIss...
# 3  001Output_combined_audio\combined_audio_YjbEAE...
# 4  001Output_combined_audio\combined_audio_aGOvk4...
#
#                                             features
# ...

# %%
df = pd.DataFrame(newdf_cleaned)

# %%
df.head()
# Out:
#                              id  label  \
# 0  iV3Db6t1T8b7c5HQY2TwxIhjbzD3      0
# 1  AxuYWBN0jFVLINCBqIW5aZmGCdu1      1
# 2  C5eIsssb9GSkaAgIfsHMHeR6fSh1      0
# 3  YjbEAECMBIaZKyfqOvWy5DDImUb2      1
# 4  aGOvk4ji0cVqIzCs1jHnzlw2UEy2      0
#
#                                           full_paths  \
# 0  ['iV3Db6t1T8b7c5HQY2TwxIhjbzD3\\breathing-deep...
# 1  ['AxuYWBN0jFVLINCBqIW5aZmGCdu1\\breathing-deep...
# 2  ['C5eIsssb9GSkaAgIfsHMHeR6fSh1\\breathing-deep...
# 3  ['YjbEAECMBIaZKyfqOvWy5DDImUb2\\breathing-deep...
# 4  ['aGOvk4ji0cVqIzCs1jHnzlw2UEy2\\breathing-deep...
#
#                                          audio_paths  \
# 0  001Output_combined_audio\combined_audio_iV3Db6...
# 1  001Output_combined_audio\combined_audio_AxuYWB...
# 2  001Output_combined_audio\combined_audio_C5eIss...
# 3  001Output_combined_audio\combined_audio_YjbEAE...
# 4  001Output_combined_audio\combined_audio_aGOvk4...
#
#                                             features
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                id  label  \
# 0    iV3Db6t1T8b7c5HQY2TwxIhjbzD3      0
# 1    AxuYWBN0jFVLINCBqIW5aZmGCdu1      1
# 2    C5eIsssb9GSkaAgIfsHMHeR6fSh1      0
# 3    YjbEAECMBIaZKyfqOvWy5DDImUb2      1
# 4    aGOvk4ji0cVqIzCs1jHnzlw2UEy2      0
# ..                            ...    ...
# 879  VRTMrYKsWURrc4AH2nNRiElqTxB3      0
# 880  AWZWqZAsydRwCkb1CSCZTjiG1YD2      1
# 881  3JXWfUZsCThwlwp2VuuS0LsfrXD2      0
# 882  Mx0Ij186LMVXmLB3xX54QCAbyhu1      0
# 883  O0oCVth5kTeHucg5KChramxKozj2      0
#
#                                             full_paths  \
# 0    ['iV3Db6t1T8b7c5HQY2TwxIhjbzD3\\breathing-deep...
# 1    ['AxuYWBN0jFVLINCBqIW5aZmGCdu1\\breathing-deep...
# 2    ['C5eIsssb9GSkaAgIfsHMHeR6fSh1\\breathing-deep...
# 3    ['YjbEAECMBIaZKyfqOvWy5DDImUb2\\breathing-deep...
# 4    ['aGOvk4ji0cVqIzCs1jHnzlw2UEy2\\breathing-deep...
# ..                                                 ...
# ...

# %%
import pandas as pd
import ast

# Read the CSV file
df = pd.read_csv('your_file.csv', header=None, names=['features'])

# Remove the enclosing quotes
df['features'] = df['features'].str.strip('"')

# Convert the string representation of the list to a list using ast.literal_eval
df['features'] = df['features'].apply(ast.literal_eval)

# Expand the list into separate columns
df = pd.DataFrame(df['features'].to_list(), columns=[f'feature_{i}' for i in range(len(df['features'].iloc[0]))])

# Display the resulting DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-c080d1511c8f> in <cell line: 8>()
#       6
#       7 # Convert the string representation of the list to a list using ast.literal_eval
# ----> 8 df['features'] = df['features'].apply(ast.literal_eval)
#       9
#      10 # Expand the list into separate columns
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# ...

# %%
import tensorflow as tf
from keras import layers, models

# Define the CNN model
def create_cnn_model(input_shape):
    model = models.Sequential()

    # Convolutional layers
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))

    # Flatten layer to transition from convolutional to fully connected layers
    model.add(layers.Flatten())

    # Fully connected layers
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(2, activation='softmax'))  # Assuming binary classification

    return model

# Assuming your input spectrogram shape is (height, width, channels)
input_shape = (15, 15, 1)  # Adjust dimensions based on your actual input shape

# Create the model
model = create_cnn_model(input_shape)

# Display the model summary
model.summary()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
ke = 8.99e9  # Coulomb's constant in N m^2/C^2
q1 = 1e-6   # Charge 1 in Coulombs
q2 = 1e-6   # Charge 2 in Coulombs
lambda_ = 1e-6  # Linear charge density in C/m

# Distance range
r = np.linspace(0.01, 1, 400)  # From 0.01 m to 1 m to avoid division by zero

# Electrostatic force between point charges
F = ke * q1 * q2 / r**2

# Electric field due to a point charge
E_point = ke * q1 / r**2

# Electric field due to an infinitely long thin wire
E_wire = 2 * ke * lambda_ / r

# Plotting
plt.figure(figsize=(12, 8))

# Electrostatic Force
plt.subplot(3, 1, 1)
plt.plot(r, F, label=r'$F = k_e \frac{q_1 q_2}{r^2}$')
plt.title('Electrostatic Force between Point Charges vs. Distance')
plt.xlabel('Distance (m)')
plt.ylabel('Force (N)')
plt.legend()
plt.grid(True)

# Electric Field due to a Point Charge
plt.subplot(3, 1, 2)
plt.plot(r, E_point, label=r'$E = k_e \frac{q}{r^2}$', color='orange')
plt.title('Electric Field due to a Point Charge vs. Distance')
plt.xlabel('Distance (m)')
plt.ylabel('Electric Field (N/C)')
plt.legend()
plt.grid(True)

# Electric Field due to an Infinitely Long Thin Wire
plt.subplot(3, 1, 3)
plt.plot(r, E_wire, label=r'$E = \frac{2k_e \lambda}{r}$', color='green')
plt.title('Electric Field due to an Infinitely Long Thin Wire vs. Distance')
plt.xlabel('Distance (m)')
plt.ylabel('Electric Field (N/C)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
